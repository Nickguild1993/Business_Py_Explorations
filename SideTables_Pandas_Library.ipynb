# %% [markdown]
# <a href="https://colab.research.google.com/github/Nickguild1993/Business_Py_Explorations/blob/main/SideTables_Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Going over the side tables library- which function as frequency tables

# %%
# !pip install sidetable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sidetable
#   Downloading sidetable-0.9.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from sidetable) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->sidetable) (1.15.0)
# Installing collected packages: sidetable
# Successfully installed sidetable-0.9.0

# %%
# import the regulars

import sidetable
import pandas as pd
import numpy as np
import seaborn as sns
from random import random

# %%
# get the data

url = "https://github.com/chris1610/pbpython/blob/master/data/school_transform.csv?raw=True"
df = pd.read_csv(url, index_col=0)
df.head(3)
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
#
#                    District Name  Model Selected  Award_Amount Region
# 0  BERING STRAIT SCHOOL DISTRICT  Transformation        471014   West
# 1         YUPIIT SCHOOL DISTRICT  Transformation        520579   West
# 2  BERING STRAIT SCHOOL DISTRICT  Transformation        449592   West

# %% [markdown]
# with sidetable imported, we have ourselves a new accessor for all the dataframes - *stb* for building summary tables.

# %%
# por exemplo 
# using .stb.freq()

df.stb.freq(["State"])[:5]
# Out:
#   State  count    percent  cumulative_count  cumulative_percent
# 0    CA     92  12.153236                92           12.153236
# 1    FL     71   9.379128               163           21.532365
# 2    PA     58   7.661823               221           29.194188
# 3    OH     35   4.623514               256           33.817701
# 4    MO     32   4.227213               288           38.044914

# %% [markdown]
# compared to using ole value_counts

# %%
df["State"].value_counts(normalize=True)[:5]
# Out:
# CA    0.121532
# FL    0.093791
# PA    0.076618
# OH    0.046235
# MO    0.042272
# Name: State, dtype: float64

# %% [markdown]
# Using the *thresh* argument to create a threshold for the returned values

# %%
df.stb.freq(["State"], thresh=30)

# Returns a frequency table with the states that make up ~ 30% of the total, with the remaining states grouped as "others"
# Out:
#     State  count    percent  cumulative_count  cumulative_percent
# 0      CA     92  12.153236                92           12.153236
# 1      FL     71   9.379128               163           21.532365
# 2      PA     58   7.661823               221           29.194188
# 3  others    536  70.805812               757          100.000000

# %%
# can pass the argument other_labels to change it

df.stb.freq(["State"], thresh=30, other_label = "The rest of em")
# Out:
#             State  count    percent  cumulative_count  cumulative_percent
# 0              CA     92  12.153236                92           12.153236
# 1              FL     71   9.379128               163           21.532365
# 2              PA     58   7.661823               221           29.194188
# 3  The rest of em    536  70.805812               757          100.000000

# %% [markdown]
# Can group columns together to further understand the distribution.  For instance, to see how the various "Transformation Models" apply across "Regions"?

# %%
df.stb.freq(["Region", "Model Selected"])[:4]
# Out:
#       Region  Model Selected  count    percent  cumulative_count  \
# 0      South  Transformation    185  24.765730               185
# 1       West  Transformation    142  19.009371               327
# 2    Midwest  Transformation    111  14.859438               438
# 3  Northeast  Transformation    102  13.654618               540
#
#    cumulative_percent
# 0           24.765730
# 1           43.775100
# 2           58.634538
# 3           72.289157

# %%
df.stb.freq(["State", "Model Selected"])[:4]
# Out:
#   State  Model Selected  count   percent  cumulative_count  cumulative_percent
# 0    CA  Transformation     56  7.397622                56            7.397622
# 1    FL  Transformation     54  7.133421               110           14.531044
# 2    PA  Transformation     43  5.680317               153           20.211361
# 3    CA      Turnaround     29  3.830911               182           24.042272

# %% [markdown]
# #### passing a value argument that can be *summed* instead of counting occurances

# %%
df.head(1)
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
#
#                    District Name  Model Selected  Award_Amount Region
# 0  BERING STRAIT SCHOOL DISTRICT  Transformation        471014   West

# %%
df.stb.freq(["Region"], value = "Award_Amount")
# Out:
#       Region  Award_Amount    percent  cumulative_Award_Amount  \
# 0      South     117467481  37.314735                117467481
# 1       West      74418552  23.639807                191886033
# 2    Midwest      65736175  20.881762                257622208
# 3  Northeast      57179654  18.163696                314801862
#
#    cumulative_percent
# 0           37.314735
# 1           60.954542
# 2           81.836304
# 3          100.000000

# %% [markdown]
# Looking at the types of models selected and determine the 80/20 breakdown of the allocated dollars

# %%
df.stb.freq(["Region", "Model Selected"],
            value = "Award_Amount", thresh = 80,
            other_label = "Those Which Remain")
# Out:
#                Region      Model Selected  Award_Amount    percent  \
# 0               South      Transformation      88680032  28.170110
# 1                West      Transformation      56207890  17.855006
# 2             Midwest      Transformation      48702505  15.470844
# 3           Northeast      Transformation      41263161  13.107661
# 4  Those Which Remain  Those Which Remain      79948274  25.396379
#
#    cumulative_Award_Amount  cumulative_percent
# 0                 88680032           28.170110
# 1                144887922           46.025116
# 2                193590427           61.495960
# 3                234853588           74.603621
# 4                314801862          100.000000

# %% [markdown]
# adding pandas style to the sidetables

# %%
df.stb.freq(["Region"], value = "Award_Amount", style =True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7091f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Region</th>
#       <th class="col_heading level0 col1" >Award_Amount</th>
#       <th class="col_heading level0 col2" >percent</th>
#       <th class="col_heading level0 col3" >cumulative_Award_Amount</th>
#       <th class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7091f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7091f_row0_col0" class="data row0 col0" >South</td>
#       <td id="T_7091f_row0_col1" class="data row0 col1" >117,467,481</td>
#       <td id="T_7091f_row0_col2" class="data row0 col2" >37.31%</td>
#       <td id="T_7091f_row0_col3" class="data row0 col3" >117,467,481</td>
#       <td id="T_7091f_row0_col4" class="data row0 col4" >37.31%</td>
#     </tr>
#     <tr>
#       <th id="T_7091f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7091f_row1_col0" class="data row1 col0" >West</td>
#       <td id="T_7091f_row1_col1" class="data row1 col1" >74,418,552</td>
#       <td id="T_7091f_row1_col2" class="data row1 col2" >23.64%</td>
#       <td id="T_7091f_row1_col3" class="data row1 col3" >191,886,033</td>
#       <td id="T_7091f_row1_col4" class="data row1 col4" >60.95%</td>
#     </tr>
#     <tr>
#       <th id="T_7091f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7091f_row2_col0" class="data row2 col0" >Midwest</td>
#       <td id="T_7091f_row2_col1" class="data row2 col1" >65,736,175</td>
#       <td id="T_7091f_row2_col2" class="data row2 col2" >20.88%</td>
#       <td id="T_7091f_row2_col3" class="data row2 col3" >257,622,208</td>
#       <td id="T_7091f_row2_col4" class="data row2 col4" >81.84%</td>
#     </tr>
#     <tr>
#       <th id="T_7091f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7091f_row3_col0" class="data row3 col0" >Northeast</td>
#       <td id="T_7091f_row3_col1" class="data row3 col1" >57,179,654</td>
#       <td id="T_7091f_row3_col2" class="data row3 col2" >18.16%</td>
#       <td id="T_7091f_row3_col3" class="data row3 col3" >314,801,862</td>
#       <td id="T_7091f_row3_col4" class="data row3 col4" >100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.stb.missing()
# Out:
#                 missing  total   percent
# Region               10    757  1.321004
# School Name           0    757  0.000000
# City                  0    757  0.000000
# State                 0    757  0.000000
# District Name         0    757  0.000000
# Model Selected        0    757  0.000000
# Award_Amount          0    757  0.000000
